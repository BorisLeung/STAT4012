# %%
"""_Action has 26363, _Adventure has 10817, _Animation has 30716, _Comedy has 83876, _Crime has 18786,
_Documentary has 108010, _Drama has 143273, _Family has 16528, _Fantasy has 12085, _History has 10142,
_Horror has 37125, _Music has 30354, _Mystery has 10789, _Romance has 32969, _Science Fiction has 12751,
_TV Movie has 17171, _Thriller has 31005, _War has 5061, _Western has 1908"""
# Out:
# '_Action has 26363, _Adventure has 10817, _Animation has 30716, _Comedy has 83876, _Crime has 18786,\n_Documentary has 108010, _Drama has 143273, _Family has 16528, _Fantasy has 12085, _History has 10142,\n_Horror has 37125, _Music has 30354, _Mystery has 10789, _Romance has 32969, _Science Fiction has 12751,\n_TV Movie has 17171, _Thriller has 31005, _War has 5061, _Western has 1908'

# %%
import tensorflow
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Activation, BatchNormalization, GroupNormalization, Dropout, Conv2D, MaxPooling2D, Flatten, Concatenate, Input
n_genre = 3

model = Sequential()
model.add(Conv2D(32, (3, 3), activation ='relu', padding = 'Same', input_shape =(345, 230, 3))) #1
model.add(GroupNormalization())
model.add(Conv2D(32, (3, 3), activation ='relu', padding = 'Same')) #2
model.add(GroupNormalization())
model.add(Conv2D(32, (3, 3), activation ='relu', padding = 'Same')) #3
model.add(GroupNormalization())
model.add(MaxPooling2D((2, 2)))
    
model.add(Conv2D(32, (3, 3), activation ='relu', padding = 'Same')) #4
model.add(GroupNormalization())
model.add(Conv2D(32, (3, 3), activation ='relu', padding = 'Same')) #5
model.add(GroupNormalization())
model.add(Conv2D(32, (3, 3), activation ='relu', padding = 'Same')) #6
model.add(GroupNormalization())
model.add(MaxPooling2D((2, 2)))
    
model.add(Conv2D(32, (3, 3), activation ='relu', padding = 'Same')) #7
model.add(GroupNormalization())
model.add(Conv2D(32, (3, 3), activation ='relu', padding = 'Same')) #8
model.add(GroupNormalization())
model.add(Conv2D(32, (3, 3), activation ='relu', padding = 'Same')) #9
model.add(GroupNormalization())
model.add(MaxPooling2D((2, 2)))
    
model.add(Conv2D(64, (3, 3), activation ='relu', padding = 'Same')) #10
model.add(GroupNormalization())
model.add(Conv2D(64, (3, 3), activation ='relu', padding = 'Same')) #11
model.add(GroupNormalization())
model.add(Conv2D(64, (3, 3), activation ='relu', padding = 'Same')) #12
model.add(GroupNormalization())
model.add(MaxPooling2D((2, 2)))
    
model.add(Flatten())
indicator_inputs = Input(shape=(6,))
concatenated_inputs = Concatenate()([model.output, indicator_inputs])
    
x = BatchNormalization()(concatenated_inputs)
x = Dense(32, activation='relu')(x)
x = Dropout(0.25)(x)
x = BatchNormalization()(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(n_genre, activation='softmax')(x)

model = Model(inputs=[model.input, indicator_inputs], outputs=output)
model.compile(optimizer='adam', loss=tensorflow.keras.losses.CategoricalCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  conv2d_12_input (InputLaye  [(None, 345, 230, 3)]        0         []
#  r)
#
#  conv2d_12 (Conv2D)          (None, 345, 230, 32)         896       ['conv2d_12_input[0][0]']
#
#  group_normalization_12 (Gr  (None, 345, 230, 32)         64        ['conv2d_12[0][0]']
#  oupNormalization)
#
#  conv2d_13 (Conv2D)          (None, 345, 230, 32)         9248      ['group_normalization_12[0][0]
#                                                                     ']
#
#  group_normalization_13 (Gr  (None, 345, 230, 32)         64        ['conv2d_13[0][0]']
#  oupNormalization)
#
#  conv2d_14 (Conv2D)          (None, 345, 230, 32)         9248      ['group_normalization_13[0][0]
#                                                                     ']
#
#  group_normalization_14 (Gr  (None, 345, 230, 32)         64        ['conv2d_14[0][0]']
#  oupNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 172, 115, 32)         0         ['group_normalization_14[0][0]
#  g2D)                                                               ']
#
#  conv2d_15 (Conv2D)          (None, 172, 115, 32)         9248      ['max_pooling2d_4[0][0]']
#
#  group_normalization_15 (Gr  (None, 172, 115, 32)         64        ['conv2d_15[0][0]']
#  oupNormalization)
#
#  conv2d_16 (Conv2D)          (None, 172, 115, 32)         9248      ['group_normalization_15[0][0]
#                                                                     ']
#
#  group_normalization_16 (Gr  (None, 172, 115, 32)         64        ['conv2d_16[0][0]']
#  oupNormalization)
#
#  conv2d_17 (Conv2D)          (None, 172, 115, 32)         9248      ['group_normalization_16[0][0]
#                                                                     ']
#
#  group_normalization_17 (Gr  (None, 172, 115, 32)         64        ['conv2d_17[0][0]']
#  oupNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 86, 57, 32)           0         ['group_normalization_17[0][0]
#  g2D)                                                               ']
#
#  conv2d_18 (Conv2D)          (None, 86, 57, 32)           9248      ['max_pooling2d_5[0][0]']
#
#  group_normalization_18 (Gr  (None, 86, 57, 32)           64        ['conv2d_18[0][0]']
#  oupNormalization)
#
#  conv2d_19 (Conv2D)          (None, 86, 57, 32)           9248      ['group_normalization_18[0][0]
#                                                                     ']
#
#  group_normalization_19 (Gr  (None, 86, 57, 32)           64        ['conv2d_19[0][0]']
#  oupNormalization)
#
#  conv2d_20 (Conv2D)          (None, 86, 57, 32)           9248      ['group_normalization_19[0][0]
#                                                                     ']
#
#  group_normalization_20 (Gr  (None, 86, 57, 32)           64        ['conv2d_20[0][0]']
#  oupNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 43, 28, 32)           0         ['group_normalization_20[0][0]
#  g2D)                                                               ']
#
#  conv2d_21 (Conv2D)          (None, 43, 28, 64)           18496     ['max_pooling2d_6[0][0]']
#
#  group_normalization_21 (Gr  (None, 43, 28, 64)           128       ['conv2d_21[0][0]']
#  oupNormalization)
#
#  conv2d_22 (Conv2D)          (None, 43, 28, 64)           36928     ['group_normalization_21[0][0]
#                                                                     ']
#
#  group_normalization_22 (Gr  (None, 43, 28, 64)           128       ['conv2d_22[0][0]']
#  oupNormalization)
#
#  conv2d_23 (Conv2D)          (None, 43, 28, 64)           36928     ['group_normalization_22[0][0]
#                                                                     ']
#
#  group_normalization_23 (Gr  (None, 43, 28, 64)           128       ['conv2d_23[0][0]']
#  oupNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 21, 14, 64)           0         ['group_normalization_23[0][0]
#  g2D)                                                               ']
#
#  flatten_1 (Flatten)         (None, 18816)                0         ['max_pooling2d_7[0][0]']
#
#  input_2 (InputLayer)        [(None, 6)]                  0         []
#
#  concatenate_1 (Concatenate  (None, 18822)                0         ['flatten_1[0][0]',
#  )                                                                   'input_2[0][0]']
#
#  batch_normalization_2 (Bat  (None, 18822)                75288     ['concatenate_1[0][0]']
#  chNormalization)
#
#  dense_3 (Dense)             (None, 32)                   602336    ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 32)                   0         ['dense_3[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32)                   128       ['dropout_2[0][0]']
#  chNormalization)
#
#  dense_4 (Dense)             (None, 64)                   2112      ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 64)                   0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 3)                    195       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 848251 (3.24 MB)
# Trainable params: 810543 (3.09 MB)
# Non-trainable params: 37708 (147.30 KB)
# __________________________________________________________________________________________________
